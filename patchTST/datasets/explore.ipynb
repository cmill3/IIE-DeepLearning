# %%
import pandas as pd

# %%
df = pd.read_csv('full.csv')

# %%
len(df)
# Out:
# 770045

# %%
df['date'].iloc[-1]
# Out:
# '2024-07-31 15:30:00-04:00'

# %%
qqq = df.loc[df['symbol'] == 'XOM']

# %%
qqq['date']
qqq['dtt'] = qqq['date'].apply(lambda x: x.split(" ")[0])
# Out:
# /var/folders/tq/_9q_lv1s2bndbr3tzzn08x4r0000gn/T/ipykernel_92908/3443178525.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qqq['dtt'] = qqq['date'].apply(lambda x: x.split(" ")[0])

# %%
x = qqq.loc[qqq['dtt'] == "2023-09-08"]

# %%
x
# Out:
#                              date          v        vw         o         c  \
# 698230  2023-09-08 09:00:00-04:00    27033.0  114.5081  114.5500  114.4000
# 698231  2023-09-08 09:30:00-04:00  1510338.0  114.8077  114.5300  115.1700
# 698232  2023-09-08 10:00:00-04:00   988993.0  115.3996  115.1600  115.5300
# 698233  2023-09-08 10:30:00-04:00  1120577.0  115.7842  115.5300  115.9000
# 698234  2023-09-08 11:00:00-04:00   644769.0  115.8561  115.9000  115.8388
# 698235  2023-09-08 11:30:00-04:00   750386.0  115.6266  115.8300  115.5527
# 698236  2023-09-08 12:00:00-04:00   540661.0  115.7732  115.5600  115.8300
# 698237  2023-09-08 12:30:00-04:00   489449.0  115.7769  115.8200  115.8600
# 698238  2023-09-08 13:00:00-04:00   420861.0  115.7504  115.8550  115.7953
# 698239  2023-09-08 13:30:00-04:00   417025.0  115.8511  115.7900  115.8865
# 698240  2023-09-08 14:00:00-04:00   838909.0  115.8435  115.8900  115.8000
# ...
