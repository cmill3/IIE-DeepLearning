# %%
import boto3
import pandas as pd
import plotly.express as px

s3 = boto3.client('s3')

# %%
## pull all the files from a specific bucket and file prefix 
def get_files(bucket, prefix):
    response = s3.list_objects_v2(Bucket=bucket, Prefix=prefix)
    files = []
    for obj in response.get('Contents', []):
        files.append(obj.get('Key'))
    return files

## take in the files, read them in, and concatenate them into a single dataframe
def read_files(bucket, files):
    dfs = []
    for file in files:
        obj = s3.get_object(Bucket=bucket, Key=file)
        df = pd.read_csv(obj['Body'])
        dfs.append(df)
    return pd.concat(dfs)

# %%
file_names = get_files('icarus-research-data', 'PTST_weekly_predictions/first_run')
df = read_files('icarus-research-data', file_names)

# %%
data = df.copy()
data = data.loc[data['symbol'] != 'META']
data['real_price_change'] = ((data['target'] - data['alert_price'])/data['alert_price']) * 100
data['predicted_price_change'] = ((data['prediction'] - data['alert_price'])/data['alert_price'])*100
data['residuals'] = (data['real_price_change'] - data['predicted_price_change'])/data['real_price_change']
data['year'] = data['date'].apply(lambda x: x.split('-')[0])

# %%
data.head()
# Out:
#    Unnamed: 0 symbol        date  hour  minute  upside_threshold_prediction  \
# 0           0    DIS  2024-01-19    10       0                            1
# 1           1   GOOG  2024-01-18    11       0                            1
# 3           3    QQQ  2024-01-18    12       0                            1
# 4           4    AMD  2024-01-16    10       0                            1
# 5           5  GOOGL  2024-01-19    11      30                            1
#
#    alert_price    strategy  downside_threshold_prediction          dt  \
# 0      93.2234  CDGAINC_2H                              0  2024-01-19
# 1     144.8500  CDGAINC_2H                              1  2024-01-18
# 3     412.4219  CDGAINC_2H                              1  2024-01-18
# 4     154.0900  CDGAINC_2H                              1  2024-01-16
# 5     146.0750  CDGAINC_2H                              0  2024-01-19
#
#      target  prediction  target_index  prediction_index  real_price_change  \
# 0   95.8900   92.989357            27                41           2.860441
# 1  150.0150  146.232773            25                39           3.565758
# 3  424.7275  414.955662            23                39           2.983741
# 4  168.6000  155.386203            27                39           9.416575
# 5  149.8550  146.218330            41                39           2.587712
#
#    predicted_price_change  residuals  year
# 0               -0.251056   1.087768  2024
# 1                0.954624   0.732280  2024
# 3                0.614362   0.794097  2024
# 4                0.841199   0.910668  2024
# 5                0.098121   0.962082  2024

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'symbol', 'date', 'hour', 'minute',
#        'upside_threshold_prediction', 'alert_price', 'strategy',
#        'downside_threshold_prediction', 'dt', 'target', 'prediction',
#        'target_index', 'prediction_index', 'real_price_change',
#        'predicted_price_change', 'residuals', 'year'],
#       dtype='object')

# %%
fig = px.scatter(
    data, x='predicted_price_change', y='real_price_change',
    title='Real vs Predicted Price Change',hover_data=['symbol'],
                 )
fig.show()

# %%
data.groupby('symbol')['residuals'].describe()
# Out:
#          count       mean         std           min       25%       50%  \
# symbol
# AAPL    1175.0       -inf         NaN          -inf -2.334445 -0.403017
# AMD     1178.0       -inf         NaN          -inf -3.268892 -0.617337
# AMZN    1145.0  -4.578214   30.001106 -7.988489e+02 -2.251974 -0.321416
# BA      1215.0       -inf         NaN          -inf -2.586744 -0.531778
# BAC       21.0  -6.315042   16.017203 -6.095928e+01 -3.226325 -0.315479
# C         15.0  -1.892572    7.022058 -2.720851e+01 -0.191808  0.015351
# DIS     1181.0        NaN         NaN          -inf -4.735040 -1.236700
# GOOG    1195.0  -4.356352   34.783981 -9.175894e+02 -2.434299 -0.421013
# GOOGL   1154.0  -3.686241   14.805441 -2.289692e+02 -2.548743 -0.530165
# IWM     1021.0       -inf         NaN          -inf -2.292882 -0.508146
# MSFT    1149.0  -2.597297   20.278425 -5.307234e+02 -1.675349 -0.319025
# NFLX    1223.0  -8.056682   68.264047 -2.105720e+03 -2.601976 -0.544922
# NKE       16.0  -1.986826    4.748230 -1.859028e+01 -2.545639 -0.108952
# NVDA    1129.0  -3.918535   25.855828 -6.580069e+02 -1.823050 -0.182191
# PYPL    1074.0  -5.578575   61.335096 -4.566532e+02 -3.443349 -0.631868
# QQQ     1111.0  -4.088566   32.457930 -8.777988e+02 -1.558621 -0.252315
# SBUX      41.0  -3.311440    9.952722 -5.596719e+01 -1.932575  0.093032
# SPY     1135.0  -3.075796   25.126949 -7.211893e+02 -1.550268 -0.222354
# TSLA    1023.0 -19.555662  414.706439 -1.319843e+04 -2.799848 -0.733583
# TSM      892.0       -inf         NaN          -inf -3.741211 -0.538842
# XOM     1226.0   0.787010   89.152816 -4.098013e+02 -1.710521 -0.184451
#
#              75%          max
# symbol
# AAPL    0.292751     4.100331
# AMD     0.347230    21.511595
# AMZN    0.367935    78.833056
# BA      0.289846   456.372030
# BAC     0.975065     3.036171
# C       0.189671     0.455734
# DIS     0.077153          inf
# GOOG    0.351828   182.977704
# GOOGL   0.340990    76.440370
# IWM     0.257257   904.269833
# MSFT    0.398591   283.310763
# NFLX    0.336846   346.781090
# NKE     0.331515     1.194298
# NVDA    0.409671     2.794286
# PYPL    0.216967  1711.378049
# QQQ     0.324833    95.258611
# SBUX    0.499301     0.824582
# SPY     0.380887   183.539808
# TSLA    0.307694   831.174348
# TSM     0.383116   879.928423
# XOM     0.400578  2642.180650

# %%
data.groupby('year')['residuals'].describe()
# Out:
#        count  mean  std  min       25%       50%       75%          max
# year
# 2021  5666.0   NaN  NaN -inf -1.995901 -0.237032  0.416341          inf
# 2022  4687.0  -inf  NaN -inf -3.108162 -0.743334  0.165449  1711.378049
# 2023  5763.0  -inf  NaN -inf -2.656430 -0.512149  0.296612   879.928423
# 2024  3203.0  -inf  NaN -inf -2.149782 -0.225971  0.428069  4244.069069
