# %%
# from helper import TimeSeriesDataset
from model import TCNClassifier
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import wandb
from sklearn.metrics import balanced_accuracy_score
import os
import random
import pandas as pd
import copy
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
from helper import prepare_data

# %%
# # Replace YOUR_API_KEY with your actual API key
# os.environ['WANDB_API_KEY'] = 'b62c5332280f3f3dec6354dacedf36d490db3aeb'
# wandb.login()

# %%
seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

dir_path = '/Users/charlesmiller/Documents/Code/DL_experiments/project_c/models/bfc_TCN/data'


device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
device
# Out:
# device(type='mps')

# %%
def prepare_model(params,features_cont,features_cat,save_model = False,model_name = 'tcn_rain'):
    # Hyper-parameters:
    tcl_num = params['tcl_num']
    tcl_channel_size = params['tcl_channel_size']
    # temporal casual layer channels
    channel_sizes = [tcl_channel_size] * tcl_num
    # convolution kernel size
    kernel_size = params['kernel_size']
    dropout = params['dropout']
    slices = 1
    use_bias = True
    lr = params['learning_rate']

    model_params = {
        'num_inputs':   len(features_cont) + len(features_cat),
        'num_classes':  2,
        'num_channels': channel_sizes,
        'kernel_size':  kernel_size,
        'dropout':      dropout,
        'slices':       slices,
        'act':          'relu',
        'use_bias':     use_bias
    }
    model = TCNClassifier(**model_params)
    return model

# %%
def train_log(loss, example_ct, epoch):
    # Where the magic happens
    # wandb.log({"epoch": epoch, "loss": loss}, step=example_ct)
    print(f"Loss after {str(example_ct).zfill(5)} examples: {loss:.3f}")

# %%
def train_model(model, X_train, y_train, X_test, y_test, criterion, optimizer, config, save_model = True, model_name = 'best_model'):
    # Tell wandb to watch what the model gets up to: gradients, weights, and more!
    # wandb.watch(model, criterion, log="all", log_freq=10)
    model = model.to(device)
    X_train, y_train = X_train.to(device), y_train.to(device)
    X_test, y_test = X_test.to(device), y_test.to(device)
    train_dataset = TensorDataset(X_train, y_train)
    test_dataset = TensorDataset(X_test, y_test)

    training_loss = []
    validation_loss = []
    example_ct = 0
    min_val_loss = 100000
    batch_size = 128
    epochs = config['epochs']

    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

    # train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    # val_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=True)
    
    for epoch in range(epochs):
        for inputs, labels in train_loader:
            # Move tensors to the right device
            inputs, labels = inputs.to(device), labels.to(device)

            prediction = model(inputs)
            loss = criterion(prediction, labels)
            example_ct +=  len(labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            val_prediction = model(inputs)
            val_loss = criterion(val_prediction, labels)

            training_loss.append(loss.item())
            validation_loss.append(val_loss.item())

        if val_loss.item() < min_val_loss:
            best_params = copy.deepcopy(model.state_dict())
            min_val_loss = val_loss.item()

        if epoch % 10 == 0:
            print(f"Epoch {epoch}: Train loss: {loss.item()}, Validation loss: {val_loss.item()}")
            # train_log(loss, example_ct, epoch)

    if save_model:
        torch.save(best_params, f'{dir_path}/{model_name}.pth')

    return min_val_loss

def build_optimizer(model, config):
    if config['optimizer'] == 'adam':
        optimizer = torch.optim.Adam(
            model.parameters(), lr=config['learning_rate'])
    elif config['optimizer'] == 'sgd':
        optimizer = torch.optim.SGD(
            model.parameters(), lr=config['learning_rate'])
    return optimizer

def make(config,features_cont,features_cat):
    # df = pd.read_csv(data_path)
    # alerts_df = pd.read_csv(alerts_path)
    # df = df.sort_values('t',ascending=True).reset_index(drop=True)
    # train_idx = int(len(df) * 0.8)
    # train = df.iloc[:train_idx]
    # test = df.iloc[train_idx:]
    # X_train, y_train = prepare_data(train,features_cont,features_cat,window_size=config['window_size'],alerts_df=alerts_df)
    # X_test, y_test = prepare_data(test,features_cont,features_cat,window_size=config['window_size'],alerts_df=alerts_df)
    model = prepare_model(config, features_cont, features_cat)
    criterion = nn.CrossEntropyLoss()
    optimizer = build_optimizer(model, config)
    
    return model, criterion, optimizer

# %%
# def test(config):
#     location = 'Sydney'
#     w = 14
#     # We pick 14 before the 2016-01-01 for the sliding window
#     from_date = '2015-12-17'
#     to_date = '2017-01-01'

#     date_fmt = '%Y-%m-%d'
#     df = get_df_complete()

#     # features
#     features_cont = ['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustSpeed', 'WindSpeed9am',
#                     'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#                     'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']
#     features_cat = ['RainToday']

#     # Assuming df is your DataFrame


#     X, Y = [], []
#     df_l = df[(df['Location'] == location) & (df.index < to_date) & (df.index > from_date)]
#     D = []
#     for f in features_cont:
#         D.append(df_l[f].interpolate('linear').fillna(0).values)
#     for f in features_cat:
#         D.append(df_l[f].map({'Yes': 1, 'No': 0}).fillna(0).values)
#         # transpose to time series
#     TS = []
#     for i in range(df_l.shape[0]):
#         row = []
#         for c in D:
#             row.append(c[i])
#         TS.append(row)
#     in_seq, out_seq = sliding_window(TS, w, 1)
#     rain_seq = [r[0][-1] for r in out_seq]
#     X.extend(in_seq)
#     Y.extend(rain_seq)

#     # X[features_cont] = scaler.fit_transform(X[features_cont])
#     X_test = torch.tensor(X).float().transpose(1, 2)

#     model_name = 'best_model'
#     model = prepare_model(config, features_cont, features_cat, model_name = model_name)
#     model = model.to(device)
#     model.load_state_dict(torch.load(f'{dir_path}/{model_name}.pth'))
#     model.eval()
#     X_test = X_test.to(device)

#     with torch.no_grad():
#         predicted_prob = model(X_test)
#         model_prediction = predicted_prob.data.max(1, keepdim = True)[1].view(-1).tolist()
#         no_rain_prediction = [0] * len(Y)
#         no_sun_prediction = [1] * len(Y)
#         coin_flip_prediction = [random.randint(0, 1) for _ in range(len(Y))]
#         tomorrow_like_today_prediction = X_test[:, -1, -1].view(-1).tolist()

#         ba_sc = balanced_accuracy_score
#         model_score = round(ba_sc(Y, model_prediction), 4)
#         no_rain_score = round(ba_sc(Y, no_rain_prediction), 4)
#         no_sun_score = round(ba_sc(Y, no_sun_prediction), 4)
#         coin_flip_score = round(ba_sc(Y, coin_flip_prediction), 4)
#         tlt_score = round(ba_sc(Y, tomorrow_like_today_prediction), 4)

#         print(f'Model Prediction Score: {model_score}')
#         print(f'No Rain Prediction Score: {no_rain_score}')
#         print(f'Rain Prediction Score: {no_sun_score}')
#         print(f'Coin Flip Prediction Score: {coin_flip_score}')
#         print(f'Tomorrow like Today Prediction Score: {tlt_score}')

#     torch.onnx.export(model, X_test, "model.onnx")
#     wandb.save("model.onnx")

# %%
def model_pipeline(hyperparameters,features_cont,features_cat,X_train, y_train, X_test, y_test):

    # # tell wandb to get started
    # with wandb.init(project="bfc-tcn", config=hyperparameters):
    #   # access all HPs through wandb.config, so logging matches execution!
    #   config = wandb.config

    # make the model, data, and optimization problem
    model,criterion, optimizer = make(hyperparameters,features_cont,features_cat)
    print(model)

    # and use them to train the model
    train_model(model, X_train, y_train, X_test, y_test, criterion, optimizer, hyperparameters)

    # # and test its final performance
    # test(config)

    return model

# %%
config = {
    "tcl_num":          2,
    "tcl_channel_size": 128,
    "kernel_size":      7,
    "dropout":          0.3,
    "slices":           1,
    "use_bias":         True,
    "learning_rate":    0.01,
    "epochs": 800,
    "classes":2,
    "batch_size": 128,
    "window_size": 20,
    "dataset" : "BFC3D_CLASSIFIER",
    "architecture": "TCN",
    "optimizer": "adam"
  }
features_cont = ['v', 'vw', 'o', 'c', 'h', 'l','n','sma_20','sma_5', 'bb_spread',
       'bb_trend','sma_20_trend', 'sma_5_trend', 'pct_5d_high','rsi','macd','roc',
       'pct_5d_low', 'stddev_close_diff_5d', 'stddev_close_diff_10d']
features_cat = ['bb_category']

# %%
data_path='/Users/charlesmiller/Documents/ts_data/day_aggs/sample_30K.csv'
alerts_path='/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2023-12-23BF3.csv'
df = pd.read_csv(data_path)
alerts_df = pd.read_csv(alerts_path)
df = df.sort_values('t',ascending=True).reset_index(drop=True)
train_idx = int(len(df) * 0.8)
train = df.iloc[:train_idx]
test = df.iloc[train_idx:]
X_train, y_train = prepare_data(train,features_cont,features_cat,window_size=config['window_size'],alerts_df=alerts_df)
X_test, y_test = prepare_data(test,features_cont,features_cat,window_size=config['window_size'],alerts_df=alerts_df)
# Out:
# Skipping PYPL-2015-07-21-12.0 due to insufficient data
# Skipping PYPL-2015-08-12-12.0 due to insufficient data
# Skipping PYPL-2015-08-13-12.0 due to insufficient data
# Skipping PYPL-2015-07-31-15.0 due to insufficient data
# Skipping PYPL-2015-07-31-13.0 due to insufficient data
# Skipping PYPL-2015-08-12-13.0 due to insufficient data
# Skipping PYPL-2015-08-03-13.0 due to insufficient data
# Skipping PYPL-2015-08-12-11.0 due to insufficient data
# Skipping SQ-2015-12-09-11.0 due to insufficient data
# Skipping SQ-2015-12-14-11.0 due to insufficient data
# Skipping SQ-2015-12-08-14.0 due to insufficient data
# Skipping SQ-2015-11-23-13.0 due to insufficient data
# Skipping SQ-2015-11-30-14.0 due to insufficient data
# Skipping SQ-2015-12-02-12.0 due to insufficient data
# Skipping SQ-2015-12-08-13.0 due to insufficient data
# Skipping SQ-2015-11-30-13.0 due to insufficient data
# Skipping SQ-2015-12-11-10.0 due to insufficient data
# Skipping DOCU-2018-05-04-15.0 due to insufficient data
# Skipping DOCU-2018-05-04-14.0 due to insufficient data
# Skipping DOCU-2018-05-18-14.0 due to insufficient data
# Skipping DOCU-2018-05-11-11.0 due to insufficient data
# Skipping DOCU-2018-05-22-11.0 due to insufficient data
# Skipping DOCU-2018-05-07-15.0 due to insufficient data
# Skipping DOCU-2018-04-30-10.0 due to insufficient data
# Skipping DOCU-2018-05-01-11.0 due to insufficient data
# Skipping DOCU-2018-05-07-12.0 due to insufficient data
# Skipping UBER-2019-06-05-15.0 due to insufficient data
# Skipping UBER-2019-06-05-13.0 due to insufficient data
# Skipping UBER-2019-05-21-14.0 due to insufficient data
# Skipping UBER-2019-06-04-13.0 due to insufficient data
# Skipping UBER-2019-06-03-14.0 due to insufficient data
# Skipping UBER-2019-05-31-12.0 due to insufficient data
# Skipping UBER-2019-05-14-11.0 due to insufficient data
# Skipping UBER-2019-05-17-12.0 due to insufficient data
# Skipping CRWD-2019-06-28-10.0 due to insufficient data
# Skipping CRWD-2019-06-14-15.0 due to insufficient data
# Skipping CRWD-2019-07-01-14.0 due to insufficient data
# Skipping CRWD-2019-06-18-11.0 due to insufficient data
# Skipping CRWD-2019-06-28-14.0 due to insufficient data
# Skipping CRWD-2019-07-05-12.0 due to insufficient data
# Skipping CRWD-2019-06-19-13.0 due to insufficient data
# Skipping CRWD-2019-06-25-14.0 due to insufficient data
# Skipping CRWD-2019-07-03-15.0 due to insufficient data
# Skipping CRWD-2019-07-02-13.0 due to insufficient data
# Skipping CRWD-2019-06-24-10.0 due to insufficient data
# Skipping SNOW-2020-10-06-13.0 due to insufficient data
# Skipping SNOW-2020-10-01-12.0 due to insufficient data
# Skipping SNOW-2020-09-18-13.0 due to insufficient data
# Skipping SNOW-2020-09-29-13.0 due to insufficient data
# Skipping SNOW-2020-09-28-10.0 due to insufficient data
# Skipping SNOW-2020-10-02-11.0 due to insufficient data
# Skipping SNOW-2020-10-01-14.0 due to insufficient data
# Skipping PLTR-2020-10-20-14.0 due to insufficient data
# Skipping PLTR-2020-10-15-15.0 due to insufficient data
# Skipping ABNB-2020-12-24-15.0 due to insufficient data
# Skipping ABNB-2020-12-18-13.0 due to insufficient data
# Skipping ABNB-2021-01-06-14.0 due to insufficient data
# Skipping ABNB-2020-12-28-11.0 due to insufficient data
# Skipping ABNB-2021-01-05-10.0 due to insufficient data
# Skipping ABNB-2020-12-23-11.0 due to insufficient data
# Skipping ABNB-2020-12-17-12.0 due to insufficient data
# Skipping ABNB-2021-01-07-11.0 due to insufficient data
# Skipping ABNB-2020-12-14-11.0 due to insufficient data
# Skipping ABNB-2020-12-14-10.0 due to insufficient data
# Skipping ABNB-2020-12-31-11.0 due to insufficient data
# Skipping C-2022-04-29-13.0 due to insufficient data
# Skipping TSM-2022-04-29-15.0 due to insufficient data
# Skipping SQ-2022-04-29-14.0 due to insufficient data
# Skipping XOM-2022-04-29-12.0 due to insufficient data
# Skipping PLTR-2022-05-04-13.0 due to insufficient data
# Skipping SPY-2022-05-04-12.0 due to insufficient data
# Skipping SBUX-2022-05-03-14.0 due to insufficient data
# Skipping C-2022-05-03-11.0 due to insufficient data
# Skipping MSFT-2022-05-02-12.0 due to insufficient data
# Skipping SBUX-2022-05-02-11.0 due to insufficient data
# Skipping INTC-2022-05-02-10.0 due to insufficient data
# Skipping BAC-2022-05-04-14.0 due to insufficient data
# Skipping AMD-2022-05-02-10.0 due to insufficient data
# Skipping AAPL-2022-05-04-15.0 due to insufficient data
# Skipping IWM-2022-05-04-11.0 due to insufficient data
# Skipping INTC-2022-05-02-15.0 due to insufficient data
# Skipping QCOM-2022-05-03-11.0 due to insufficient data
# Skipping BA-2022-05-03-12.0 due to insufficient data
# Skipping QQQ-2022-05-04-12.0 due to insufficient data
# Skipping MSFT-2022-05-02-11.0 due to insufficient data
# Skipping CVX-2022-05-02-14.0 due to insufficient data
# Skipping AMD-2022-05-04-11.0 due to insufficient data
# Skipping NKE-2022-05-04-15.0 due to insufficient data
# Skipping UBER-2022-05-03-14.0 due to insufficient data
# Skipping AAPL-2022-05-02-10.0 due to insufficient data
# Skipping AVGO-2022-05-03-10.0 due to insufficient data
# Skipping AAPL-2022-05-03-12.0 due to insufficient data
# Skipping JPM-2022-05-02-10.0 due to insufficient data
# Skipping JPM-2022-05-03-15.0 due to insufficient data
# Skipping ADBE-2022-05-02-10.0 due to insufficient data
# Skipping AMZN-2022-05-03-14.0 due to insufficient data
# Skipping BA-2022-05-03-13.0 due to insufficient data
# Skipping C-2022-05-02-10.0 due to insufficient data
# Skipping BAC-2022-05-02-14.0 due to insufficient data
# Skipping SBUX-2022-05-03-12.0 due to insufficient data
# Skipping UBER-2022-05-04-12.0 due to insufficient data
# Skipping DIS-2022-05-02-14.0 due to insufficient data
# Skipping NKE-2022-05-02-15.0 due to insufficient data
# Skipping QCOM-2022-05-03-14.0 due to insufficient data
# Skipping AXP-2022-05-03-11.0 due to insufficient data
# Skipping WMT-2022-05-04-15.0 due to insufficient data
# Skipping TSM-2022-05-03-13.0 due to insufficient data
# Skipping SNOW-2022-05-03-10.0 due to insufficient data
# Skipping AVGO-2022-05-02-11.0 due to insufficient data
# Skipping INTC-2022-05-04-12.0 due to insufficient data
# Skipping SNOW-2022-05-04-13.0 due to insufficient data
# Skipping SBUX-2022-05-03-15.0 due to insufficient data
# Skipping GOOGL-2022-05-02-10.0 due to insufficient data
# Skipping AAPL-2022-05-02-15.0 due to insufficient data
# Skipping PYPL-2022-05-04-12.0 due to insufficient data
# Skipping QQQ-2022-05-02-15.0 due to insufficient data
# Skipping ABNB-2022-05-02-14.0 due to insufficient data
# Skipping SPY-2022-05-03-12.0 due to insufficient data
# Skipping AMD-2022-05-03-15.0 due to insufficient data
# Skipping XOM-2022-05-04-10.0 due to insufficient data
# Skipping BAC-2022-05-02-11.0 due to insufficient data
# Skipping DIS-2022-05-02-15.0 due to insufficient data
# Skipping CVX-2022-05-02-15.0 due to insufficient data
# Skipping DOCU-2022-05-04-13.0 due to insufficient data
# Skipping PLTR-2022-05-02-13.0 due to insufficient data
# Skipping DOCU-2022-05-04-15.0 due to insufficient data
# Skipping AMZN-2022-05-05-15.0 due to insufficient data
# Skipping AVGO-2022-05-05-15.0 due to insufficient data
# Skipping PYPL-2022-05-05-15.0 due to insufficient data
# Skipping C-2022-05-05-13.0 due to insufficient data
# Skipping NVDA-2022-05-05-14.0 due to insufficient data
# Skipping UBER-2022-05-05-12.0 due to insufficient data
# Skipping MSFT-2022-05-05-11.0 due to insufficient data
# Skipping IWM-2022-05-05-13.0 due to insufficient data
# Skipping AMZN-2022-05-05-13.0 due to insufficient data
# Skipping INTC-2022-05-05-12.0 due to insufficient data
# Skipping NKE-2022-05-05-15.0 due to insufficient data
# Skipping SNOW-2022-05-05-15.0 due to insufficient data
# Skipping IWM-2022-05-05-12.0 due to insufficient data
# Skipping SQ-2022-05-05-13.0 due to insufficient data
# Skipping BA-2022-05-05-15.0 due to insufficient data
# Skipping V-2022-05-05-13.0 due to insufficient data
# Skipping MSFT-2022-05-05-13.0 due to insufficient data
# Skipping AXP-2022-05-05-13.0 due to insufficient data
# Skipping GOOGL-2022-05-06-12.0 due to insufficient data
# Skipping UBER-2022-05-06-13.0 due to insufficient data
# Skipping DIS-2022-05-06-14.0 due to insufficient data
# Skipping DOCU-2022-05-06-10.0 due to insufficient data
# Skipping BA-2022-05-06-14.0 due to insufficient data
# Skipping IWM-2022-05-06-13.0 due to insufficient data
# Skipping NVDA-2022-05-06-10.0 due to insufficient data
# Skipping INTC-2022-05-06-11.0 due to insufficient data
# Skipping PYPL-2022-05-06-10.0 due to insufficient data
# Skipping SQ-2022-05-06-14.0 due to insufficient data
# Skipping ABNB-2022-05-06-10.0 due to insufficient data
# Skipping JPM-2022-05-06-10.0 due to insufficient data
# Skipping BAC-2022-05-06-15.0 due to insufficient data
# Skipping GM-2022-05-06-12.0 due to insufficient data
# Skipping UBER-2022-05-06-15.0 due to insufficient data
# Skipping SPY-2022-05-06-14.0 due to insufficient data
# Skipping CVX-2022-05-10-14.0 due to insufficient data
# Skipping AMD-2022-05-09-12.0 due to insufficient data
# Skipping QQQ-2022-05-09-14.0 due to insufficient data
# Skipping GOOGL-2022-05-09-12.0 due to insufficient data
# Skipping NFLX-2022-05-09-11.0 due to insufficient data
# Skipping AXP-2022-05-09-10.0 due to insufficient data
# Skipping SQ-2022-05-09-14.0 due to insufficient data
# Skipping BAC-2022-05-10-13.0 due to insufficient data
# Skipping BA-2022-05-10-13.0 due to insufficient data
# Skipping CSCO-2022-05-09-14.0 due to insufficient data
# Skipping ABNB-2022-05-10-14.0 due to insufficient data
# Skipping QCOM-2022-05-10-12.0 due to insufficient data
# Skipping TSM-2022-05-10-10.0 due to insufficient data
# Skipping AMD-2022-05-09-15.0 due to insufficient data
# Skipping NFLX-2022-05-10-12.0 due to insufficient data
# Skipping BA-2022-05-10-14.0 due to insufficient data
# Skipping C-2022-05-10-14.0 due to insufficient data
# Skipping AVGO-2022-05-10-10.0 due to insufficient data
# Skipping SPY-2022-05-10-13.0 due to insufficient data
# Skipping ABNB-2022-05-09-15.0 due to insufficient data
# Skipping TGT-2022-05-09-11.0 due to insufficient data
# Skipping PYPL-2022-05-09-15.0 due to insufficient data
# Skipping AMD-2022-05-09-10.0 due to insufficient data
# Skipping UBER-2022-05-09-14.0 due to insufficient data
# Skipping QCOM-2022-05-09-15.0 due to insufficient data
# Skipping TGT-2022-05-10-10.0 due to insufficient data
# Skipping QQQ-2022-05-09-12.0 due to insufficient data
# Skipping GOOG-2022-05-10-14.0 due to insufficient data
# Skipping ABNB-2022-05-10-13.0 due to insufficient data
# Skipping AAPL-2022-05-09-11.0 due to insufficient data
# Skipping ABNB-2022-05-10-10.0 due to insufficient data
# Skipping CSCO-2022-05-09-12.0 due to insufficient data
# Skipping ABNB-2022-05-11-12.0 due to insufficient data
# Skipping GM-2022-05-11-11.0 due to insufficient data
# Skipping SQ-2022-05-11-13.0 due to insufficient data
# Skipping TSM-2022-05-11-15.0 due to insufficient data
# Skipping CVX-2022-05-11-14.0 due to insufficient data
# Skipping INTC-2022-05-11-13.0 due to insufficient data
# Skipping SQ-2022-05-11-12.0 due to insufficient data
# Skipping QQQ-2022-05-11-13.0 due to insufficient data
# Skipping CSCO-2022-05-11-14.0 due to insufficient data
# Skipping BA-2022-05-11-13.0 due to insufficient data
# Skipping WMT-2022-05-11-12.0 due to insufficient data
# Skipping SPY-2022-05-11-11.0 due to insufficient data
# Skipping SNOW-2022-05-11-12.0 due to insufficient data
# Skipping GOOGL-2022-05-11-15.0 due to insufficient data
# Skipping XOM-2022-05-11-13.0 due to insufficient data
# Skipping QCOM-2022-05-11-13.0 due to insufficient data
# Skipping C-2022-05-11-12.0 due to insufficient data
# Skipping NVDA-2022-05-11-15.0 due to insufficient data
# Skipping UBER-2022-05-11-10.0 due to insufficient data
# Skipping PLTR-2022-05-11-15.0 due to insufficient data
# Skipping TSM-2022-05-12-15.0 due to insufficient data
# Skipping AXP-2022-05-12-12.0 due to insufficient data
# Skipping PLTR-2022-05-12-12.0 due to insufficient data
# Skipping AMZN-2022-05-12-10.0 due to insufficient data
# Skipping DIS-2022-05-12-14.0 due to insufficient data
# Skipping XOM-2022-05-12-15.0 due to insufficient data
# Skipping GOOGL-2022-05-12-11.0 due to insufficient data
# Skipping CSCO-2022-05-12-13.0 due to insufficient data
# Skipping GOOGL-2022-05-12-13.0 due to insufficient data
# Skipping GOOG-2022-05-12-11.0 due to insufficient data
# Skipping GOOGL-2022-05-13-13.0 due to insufficient data
# Skipping AXP-2022-05-13-11.0 due to insufficient data
# Skipping NFLX-2022-05-13-12.0 due to insufficient data
# Skipping NVDA-2022-05-13-10.0 due to insufficient data
# Skipping SPY-2022-05-13-12.0 due to insufficient data
# Skipping BA-2022-05-13-12.0 due to insufficient data
# Skipping PLTR-2022-05-13-14.0 due to insufficient data
# Skipping BAC-2022-05-13-11.0 due to insufficient data
# Skipping CSCO-2022-05-13-12.0 due to insufficient data
# Skipping GM-2022-05-13-11.0 due to insufficient data
# Skipping SQ-2022-05-13-11.0 due to insufficient data
# Skipping AVGO-2022-05-16-14.0 due to insufficient data
# Skipping NFLX-2022-05-16-14.0 due to insufficient data
# Skipping QCOM-2022-05-17-10.0 due to insufficient data
# Skipping WMT-2022-05-16-12.0 due to insufficient data
# Skipping AVGO-2022-05-17-10.0 due to insufficient data
# Skipping C-2022-05-17-10.0 due to insufficient data
# Skipping PLTR-2022-05-17-13.0 due to insufficient data
# Skipping AMZN-2022-05-16-12.0 due to insufficient data
# Skipping XOM-2022-05-16-13.0 due to insufficient data
# Skipping WMT-2022-05-17-13.0 due to insufficient data
# Skipping JPM-2022-05-16-13.0 due to insufficient data
# Skipping INTC-2022-05-16-12.0 due to insufficient data
# Skipping GOOG-2022-05-17-12.0 due to insufficient data
# Skipping ADBE-2022-05-16-11.0 due to insufficient data
# Skipping GM-2022-05-16-15.0 due to insufficient data
# Skipping GOOG-2022-05-16-10.0 due to insufficient data
# Skipping TGT-2022-05-17-14.0 due to insufficient data
# Skipping DOCU-2022-05-17-10.0 due to insufficient data
# Skipping JPM-2022-05-17-13.0 due to insufficient data
# Skipping BA-2022-05-16-13.0 due to insufficient data
# Skipping JPM-2022-05-16-12.0 due to insufficient data
# Skipping JPM-2022-05-17-14.0 due to insufficient data
# Skipping AAPL-2022-05-16-14.0 due to insufficient data
# Skipping IWM-2022-05-17-13.0 due to insufficient data
# Skipping IWM-2022-05-17-15.0 due to insufficient data
# Skipping NVDA-2022-05-17-14.0 due to insufficient data
# Skipping MSFT-2022-05-16-11.0 due to insufficient data
# Skipping ABNB-2022-05-17-13.0 due to insufficient data
# Skipping PLTR-2022-05-16-13.0 due to insufficient data
# Skipping NVDA-2022-05-18-15.0 due to insufficient data
# Skipping GM-2022-05-18-11.0 due to insufficient data
# Skipping SBUX-2022-05-18-13.0 due to insufficient data
# Skipping UBER-2022-05-18-13.0 due to insufficient data
# Skipping AMD-2022-05-18-15.0 due to insufficient data
# Skipping BAC-2022-05-18-12.0 due to insufficient data
# Skipping NFLX-2022-05-18-11.0 due to insufficient data
# Skipping WMT-2022-05-18-10.0 due to insufficient data
# Skipping AMZN-2022-05-18-15.0 due to insufficient data
# Skipping AAPL-2022-05-18-13.0 due to insufficient data
# Skipping CSCO-2022-05-18-13.0 due to insufficient data
# Skipping CVX-2022-05-18-14.0 due to insufficient data
# Skipping C-2022-05-18-11.0 due to insufficient data
# Skipping BAC-2022-05-18-14.0 due to insufficient data
# Skipping SQ-2022-05-18-12.0 due to insufficient data
# Skipping GOOG-2022-05-18-13.0 due to insufficient data
# Skipping PLTR-2022-05-18-12.0 due to insufficient data
# Skipping JPM-2022-05-19-12.0 due to insufficient data
# Skipping CSCO-2022-05-19-11.0 due to insufficient data
# Skipping SBUX-2022-05-19-11.0 due to insufficient data
# Skipping GM-2022-05-19-12.0 due to insufficient data
# Skipping PYPL-2022-05-19-11.0 due to insufficient data
# Skipping ABNB-2022-05-19-10.0 due to insufficient data
# Skipping SQ-2022-05-19-12.0 due to insufficient data
# Skipping INTC-2022-05-19-13.0 due to insufficient data
# Skipping C-2022-05-19-12.0 due to insufficient data
# Skipping V-2022-05-19-14.0 due to insufficient data
# Skipping AVGO-2022-05-19-11.0 due to insufficient data
# Skipping SQ-2022-05-19-11.0 due to insufficient data
# Skipping DIS-2022-05-19-12.0 due to insufficient data
# Skipping TSM-2022-05-19-15.0 due to insufficient data
# Skipping UBER-2022-05-19-11.0 due to insufficient data
# Skipping AMD-2022-05-19-14.0 due to insufficient data
# Skipping NFLX-2022-05-20-12.0 due to insufficient data
# Skipping BA-2022-05-20-10.0 due to insufficient data
# Skipping JPM-2022-05-20-15.0 due to insufficient data
# Skipping AMD-2022-05-20-15.0 due to insufficient data
# Skipping MSFT-2022-05-20-10.0 due to insufficient data
# Skipping ABNB-2022-05-20-15.0 due to insufficient data
# Skipping NVDA-2022-05-20-10.0 due to insufficient data
# Skipping MSFT-2022-05-20-15.0 due to insufficient data
# Skipping SPY-2022-05-20-14.0 due to insufficient data
# Skipping GM-2022-05-20-14.0 due to insufficient data
# Skipping QQQ-2022-05-24-15.0 due to insufficient data
# Skipping CSCO-2022-05-23-10.0 due to insufficient data
# Skipping QCOM-2022-05-23-15.0 due to insufficient data
# Skipping IWM-2022-05-23-14.0 due to insufficient data
# Skipping GOOG-2022-05-23-11.0 due to insufficient data
# Skipping UBER-2022-05-24-10.0 due to insufficient data
# Skipping CVX-2022-05-23-10.0 due to insufficient data
# Skipping AMD-2022-05-24-11.0 due to insufficient data
# Skipping PLTR-2022-05-23-15.0 due to insufficient data
# Skipping XOM-2022-05-23-12.0 due to insufficient data
# Skipping SBUX-2022-05-24-10.0 due to insufficient data
# Skipping AAPL-2022-05-24-14.0 due to insufficient data
# Skipping AXP-2022-05-24-10.0 due to insufficient data
# Skipping BAC-2022-05-24-10.0 due to insufficient data
# Skipping DOCU-2022-05-24-12.0 due to insufficient data
# Skipping MSFT-2022-05-23-13.0 due to insufficient data
# Skipping PLTR-2022-05-23-10.0 due to insufficient data
# Skipping BA-2022-05-23-12.0 due to insufficient data
# Skipping SPY-2022-05-24-14.0 due to insufficient data
# Skipping XOM-2022-05-24-10.0 due to insufficient data
# Skipping V-2022-05-24-13.0 due to insufficient data
# Skipping AXP-2022-05-24-12.0 due to insufficient data
# Skipping AVGO-2022-05-24-10.0 due to insufficient data
# Skipping ABNB-2022-05-23-13.0 due to insufficient data
# Skipping NKE-2022-05-23-10.0 due to insufficient data
# Skipping GM-2022-05-24-15.0 due to insufficient data
# Skipping MSFT-2022-05-24-10.0 due to insufficient data
# Skipping SNOW-2022-05-24-10.0 due to insufficient data
# Skipping SQ-2022-05-23-15.0 due to insufficient data
# Skipping QQQ-2022-05-23-12.0 due to insufficient data
# Skipping GOOGL-2022-05-23-14.0 due to insufficient data
# Skipping CVX-2022-05-24-11.0 due to insufficient data
# Skipping AAPL-2022-05-24-11.0 due to insufficient data
# Skipping QQQ-2022-05-23-14.0 due to insufficient data
# Skipping ABNB-2022-05-23-12.0 due to insufficient data
# Skipping TGT-2022-05-23-15.0 due to insufficient data
# Skipping SQ-2022-05-25-14.0 due to insufficient data
# Skipping NKE-2022-05-25-10.0 due to insufficient data
# Skipping CSCO-2022-05-25-14.0 due to insufficient data
# Skipping AMZN-2022-05-25-10.0 due to insufficient data
# Skipping TGT-2022-05-25-12.0 due to insufficient data
# Skipping TGT-2022-05-25-13.0 due to insufficient data
# Skipping ABNB-2022-05-25-13.0 due to insufficient data
# Skipping QCOM-2022-05-25-12.0 due to insufficient data
# Skipping INTC-2022-05-25-10.0 due to insufficient data
# Skipping NKE-2022-05-25-13.0 due to insufficient data
# Skipping DIS-2022-05-26-12.0 due to insufficient data
# Skipping GOOG-2022-05-26-13.0 due to insufficient data
# Skipping DIS-2022-05-26-11.0 due to insufficient data
# Skipping PLTR-2022-05-26-14.0 due to insufficient data
# Skipping CVX-2022-05-26-15.0 due to insufficient data
# Skipping MSFT-2022-05-26-12.0 due to insufficient data
# Skipping PLTR-2022-05-26-12.0 due to insufficient data
# Skipping SBUX-2022-05-26-11.0 due to insufficient data
# Skipping NFLX-2022-05-26-12.0 due to insufficient data
# Skipping C-2022-05-26-10.0 due to insufficient data
# Skipping IWM-2022-05-26-11.0 due to insufficient data
# Skipping AVGO-2022-05-26-13.0 due to insufficient data
# Skipping SPY-2022-05-26-15.0 due to insufficient data
# Skipping AAPL-2022-05-26-12.0 due to insufficient data
# Skipping DOCU-2022-05-26-10.0 due to insufficient data
# Skipping XOM-2022-05-26-13.0 due to insufficient data
# Skipping JPM-2022-05-26-11.0 due to insufficient data
# Skipping MSFT-2022-05-27-13.0 due to insufficient data
# Skipping TSM-2022-05-27-11.0 due to insufficient data
# Skipping UBER-2022-05-27-13.0 due to insufficient data
# Skipping BA-2022-05-27-11.0 due to insufficient data
# Skipping SQ-2022-05-27-13.0 due to insufficient data
# Skipping C-2022-05-27-12.0 due to insufficient data
# Skipping DIS-2022-02-22-12.0 due to insufficient data
# Skipping ABNB-2022-03-09-12.0 due to insufficient data
# Skipping NKE-2022-02-14-10.0 due to insufficient data
# Skipping SQ-2022-03-04-14.0 due to insufficient data
# Skipping ADBE-2022-02-23-11.0 due to insufficient data
# Skipping NFLX-2022-02-23-15.0 due to insufficient data
# Skipping V-2022-02-24-14.0 due to insufficient data
# Skipping BAC-2022-02-11-10.0 due to insufficient data
# Skipping NVDA-2022-03-01-12.0 due to insufficient data
# Skipping GOOG-2022-02-23-12.0 due to insufficient data
# Skipping MSFT-2022-03-08-13.0 due to insufficient data
# Skipping AMZN-2022-03-01-14.0 due to insufficient data
# Skipping ABNB-2022-02-11-15.0 due to insufficient data
# Skipping AXP-2022-02-18-11.0 due to insufficient data
# Skipping AMZN-2022-02-23-15.0 due to insufficient data
# Skipping BA-2022-02-24-14.0 due to insufficient data
# Skipping AVGO-2022-03-08-12.0 due to insufficient data
# Skipping GM-2022-02-23-13.0 due to insufficient data
# Skipping SQ-2022-03-03-15.0 due to insufficient data
# Skipping BA-2022-03-02-10.0 due to insufficient data
# Skipping SQ-2022-02-24-10.0 due to insufficient data
# Skipping V-2022-02-25-15.0 due to insufficient data
# Skipping INTC-2022-03-02-15.0 due to insufficient data
# Skipping DOCU-2022-02-11-14.0 due to insufficient data
# Skipping AMD-2022-03-01-14.0 due to insufficient data
# Skipping SBUX-2022-03-09-14.0 due to insufficient data
# Skipping JPM-2022-02-15-15.0 due to insufficient data
# Skipping TSM-2022-02-17-12.0 due to insufficient data
# Skipping C-2022-02-14-14.0 due to insufficient data
# Skipping V-2022-02-14-14.0 due to insufficient data
# Skipping PLTR-2022-02-17-10.0 due to insufficient data
# Skipping AAPL-2022-03-08-10.0 due to insufficient data
# Skipping C-2022-03-08-10.0 due to insufficient data
# Skipping C-2022-02-22-13.0 due to insufficient data
# Skipping NKE-2022-02-15-14.0 due to insufficient data
# Skipping TGT-2022-03-09-10.0 due to insufficient data
# Skipping SQ-2022-03-01-15.0 due to insufficient data
# Skipping JPM-2022-03-04-12.0 due to insufficient data
# Skipping MSFT-2022-02-16-11.0 due to insufficient data
# Skipping DIS-2022-03-08-11.0 due to insufficient data
# Skipping CVX-2022-02-16-11.0 due to insufficient data
# Skipping BAC-2022-02-23-13.0 due to insufficient data
# Skipping TSM-2022-03-02-11.0 due to insufficient data
# Skipping XOM-2022-02-28-14.0 due to insufficient data
# Skipping TSM-2022-02-14-14.0 due to insufficient data
# Skipping SPY-2022-02-15-11.0 due to insufficient data
# Skipping WMT-2022-02-25-11.0 due to insufficient data
# Skipping AAPL-2022-02-17-14.0 due to insufficient data
# Skipping UBER-2022-03-04-14.0 due to insufficient data
# Skipping AVGO-2022-02-17-13.0 due to insufficient data
# Skipping SQ-2022-02-28-15.0 due to insufficient data
# Skipping BAC-2022-03-08-12.0 due to insufficient data
# Skipping CVX-2022-02-16-13.0 due to insufficient data
# Skipping INTC-2022-03-09-13.0 due to insufficient data
# Skipping SPY-2022-02-16-13.0 due to insufficient data
# Skipping V-2022-03-09-14.0 due to insufficient data
# Skipping BAC-2022-02-25-11.0 due to insufficient data
# Skipping JPM-2022-02-18-13.0 due to insufficient data
# Skipping INTC-2022-02-15-13.0 due to insufficient data
# Skipping BA-2022-03-04-15.0 due to insufficient data
# Skipping PLTR-2022-03-01-15.0 due to insufficient data
# Skipping AMD-2022-03-04-15.0 due to insufficient data
# Skipping AMD-2022-02-15-15.0 due to insufficient data
# Skipping WMT-2022-02-28-13.0 due to insufficient data
# Skipping PYPL-2022-03-09-15.0 due to insufficient data
# Skipping NKE-2022-03-03-15.0 due to insufficient data
# Skipping XOM-2022-03-01-12.0 due to insufficient data
# Skipping QQQ-2022-02-11-15.0 due to insufficient data
# Skipping QCOM-2022-02-11-10.0 due to insufficient data
# Skipping QQQ-2022-02-16-11.0 due to insufficient data
# Skipping C-2022-02-25-10.0 due to insufficient data
# Skipping GM-2022-02-22-12.0 due to insufficient data
# Skipping NFLX-2022-02-22-11.0 due to insufficient data
# Skipping SNOW-2022-03-03-15.0 due to insufficient data
# Skipping IWM-2022-03-09-15.0 due to insufficient data
# Skipping AXP-2022-03-01-11.0 due to insufficient data
# Skipping XOM-2022-03-01-13.0 due to insufficient data
# Skipping PYPL-2022-03-03-12.0 due to insufficient data
# Skipping NKE-2022-02-15-11.0 due to insufficient data
# Skipping PLTR-2022-02-16-12.0 due to insufficient data
# Skipping GOOG-2022-03-08-11.0 due to insufficient data
# Skipping AMZN-2022-02-16-15.0 due to insufficient data
# Skipping INTC-2022-02-28-13.0 due to insufficient data
# Skipping SPY-2022-03-03-13.0 due to insufficient data
# Skipping DOCU-2022-02-24-15.0 due to insufficient data
# Skipping IWM-2022-02-11-14.0 due to insufficient data
# Skipping CVX-2022-02-24-12.0 due to insufficient data
# Skipping JPM-2022-02-24-11.0 due to insufficient data
# Skipping QCOM-2022-02-11-14.0 due to insufficient data
# Skipping JPM-2022-02-22-15.0 due to insufficient data
# Skipping PYPL-2022-03-02-13.0 due to insufficient data
# Skipping NKE-2022-03-02-10.0 due to insufficient data
# Skipping SNOW-2022-03-02-10.0 due to insufficient data
# Skipping UBER-2022-02-16-11.0 due to insufficient data
# Skipping SQ-2022-02-10-10.0 due to insufficient data
# Skipping XOM-2022-02-10-10.0 due to insufficient data
# Skipping PLTR-2022-02-10-10.0 due to insufficient data
# Skipping NVDA-2022-02-10-11.0 due to insufficient data
# Skipping SPY-2022-02-10-11.0 due to insufficient data
# Skipping CVX-2022-02-10-12.0 due to insufficient data
# Skipping C-2022-02-10-12.0 due to insufficient data
# Skipping AVGO-2022-02-10-12.0 due to insufficient data
# Skipping AXP-2022-02-10-12.0 due to insufficient data
# Skipping GOOGL-2022-02-10-13.0 due to insufficient data
# Skipping MSFT-2022-02-10-13.0 due to insufficient data
# Skipping JPM-2022-02-10-13.0 due to insufficient data
# Skipping SNOW-2022-02-10-14.0 due to insufficient data
# Skipping CVX-2022-02-10-14.0 due to insufficient data
# Skipping UBER-2022-02-10-15.0 due to insufficient data
# Skipping SBUX-2022-02-10-15.0 due to insufficient data
# Skipping TGT-2022-02-10-15.0 due to insufficient data
# Skipping DOCU-2022-03-09-10.0 due to insufficient data
# Skipping TSM-2022-03-04-12.0 due to insufficient data
# Skipping PLTR-2022-02-25-12.0 due to insufficient data
# Skipping AVGO-2022-03-07-13.0 due to insufficient data
# Skipping SNOW-2022-02-15-13.0 due to insufficient data
# Skipping GOOGL-2022-03-02-11.0 due to insufficient data
# Skipping JPM-2022-03-02-12.0 due to insufficient data
# Skipping SQ-2022-02-18-12.0 due to insufficient data
# Skipping UBER-2022-02-28-15.0 due to insufficient data
# Skipping BA-2022-03-04-12.0 due to insufficient data
# Skipping BAC-2022-02-15-10.0 due to insufficient data
# Skipping V-2022-02-17-14.0 due to insufficient data
# Skipping QCOM-2022-02-15-13.0 due to insufficient data
# Skipping MSFT-2022-02-16-12.0 due to insufficient data
# Skipping WMT-2022-03-02-12.0 due to insufficient data
# Skipping IWM-2022-03-01-15.0 due to insufficient data
# Skipping DIS-2022-02-14-13.0 due to insufficient data
# Skipping UBER-2022-02-17-12.0 due to insufficient data
# Skipping QCOM-2022-02-28-12.0 due to insufficient data
# Skipping DIS-2022-03-04-13.0 due to insufficient data
# Skipping DOCU-2022-02-17-13.0 due to insufficient data
# Skipping V-2022-03-01-13.0 due to insufficient data
# Skipping NKE-2022-03-03-10.0 due to insufficient data
# Skipping TGT-2022-02-15-11.0 due to insufficient data
# Skipping GM-2022-03-04-12.0 due to insufficient data
# Skipping SNOW-2022-03-04-12.0 due to insufficient data
# Skipping AMZN-2022-03-09-12.0 due to insufficient data
# Skipping PYPL-2022-02-24-12.0 due to insufficient data
# Skipping AXP-2022-02-18-13.0 due to insufficient data
# Skipping AXP-2022-02-22-15.0 due to insufficient data
# Skipping BAC-2022-02-28-10.0 due to insufficient data
# Skipping DIS-2022-02-17-11.0 due to insufficient data
# Skipping AXP-2022-02-28-11.0 due to insufficient data
# Skipping SNOW-2022-02-23-13.0 due to insufficient data
# Skipping WMT-2022-03-10-10.0 due to insufficient data
# Skipping ABNB-2022-02-28-14.0 due to insufficient data
# Skipping SBUX-2022-03-10-12.0 due to insufficient data
# Skipping ADBE-2022-03-07-15.0 due to insufficient data
# Skipping WMT-2022-02-15-15.0 due to insufficient data
# Skipping SPY-2022-02-17-12.0 due to insufficient data
# Skipping V-2022-02-28-12.0 due to insufficient data
# Skipping QQQ-2022-02-18-15.0 due to insufficient data
# Skipping BAC-2022-02-16-12.0 due to insufficient data
# Skipping NVDA-2022-03-10-11.0 due to insufficient data
# Skipping SBUX-2022-02-28-11.0 due to insufficient data
# Skipping IWM-2022-03-07-11.0 due to insufficient data
# Skipping INTC-2022-02-28-10.0 due to insufficient data
# Skipping BAC-2022-03-03-10.0 due to insufficient data
# Skipping CVX-2022-02-24-13.0 due to insufficient data
# Skipping MSFT-2022-02-28-12.0 due to insufficient data
# Skipping AVGO-2022-03-04-11.0 due to insufficient data
# Skipping JPM-2022-03-03-13.0 due to insufficient data
# Skipping DIS-2022-03-07-10.0 due to insufficient data
# Skipping CVX-2022-03-03-15.0 due to insufficient data
# Skipping GM-2022-03-03-14.0 due to insufficient data
# Skipping NKE-2022-03-01-10.0 due to insufficient data
# Skipping UBER-2022-02-25-15.0 due to insufficient data
# Skipping AMD-2022-03-09-12.0 due to insufficient data
# Skipping UBER-2022-03-09-15.0 due to insufficient data
# Skipping AAPL-2022-02-28-14.0 due to insufficient data
# Skipping BA-2022-02-24-12.0 due to insufficient data
# Skipping GOOG-2022-02-22-14.0 due to insufficient data
# Skipping PYPL-2022-03-10-12.0 due to insufficient data
# Skipping SBUX-2022-03-02-14.0 due to insufficient data
# Skipping AAPL-2022-02-23-13.0 due to insufficient data
# Skipping CSCO-2022-03-07-11.0 due to insufficient data
# Skipping C-2022-02-17-13.0 due to insufficient data
# Skipping XOM-2022-02-15-13.0 due to insufficient data
# Skipping ABNB-2022-03-09-14.0 due to insufficient data
# Skipping TSM-2022-03-09-15.0 due to insufficient data
# Skipping GM-2022-02-23-15.0 due to insufficient data
# Skipping BA-2022-02-22-11.0 due to insufficient data
# Skipping DIS-2022-02-24-13.0 due to insufficient data
# Skipping UBER-2022-02-18-15.0 due to insufficient data
# Skipping CSCO-2022-03-01-14.0 due to insufficient data
# Skipping IWM-2022-02-16-11.0 due to insufficient data
# Skipping WMT-2022-03-03-14.0 due to insufficient data
# Skipping GOOGL-2022-02-28-11.0 due to insufficient data
# Skipping QCOM-2022-02-15-11.0 due to insufficient data
# Skipping TGT-2022-03-03-15.0 due to insufficient data
# Skipping AXP-2022-03-02-11.0 due to insufficient data
# Skipping ADBE-2022-03-01-11.0 due to insufficient data
# Skipping TSM-2022-03-02-13.0 due to insufficient data
# Skipping QQQ-2022-03-02-12.0 due to insufficient data
# Skipping XOM-2022-03-10-10.0 due to insufficient data
# Skipping ADBE-2022-03-04-12.0 due to insufficient data
# Skipping GM-2022-02-25-15.0 due to insufficient data
# Skipping NKE-2022-03-10-15.0 due to insufficient data
# Skipping V-2022-02-15-12.0 due to insufficient data
# Skipping C-2022-02-16-15.0 due to insufficient data
# Skipping UBER-2022-02-18-10.0 due to insufficient data
# Skipping GOOG-2022-03-08-10.0 due to insufficient data
# Skipping GM-2022-02-18-14.0 due to insufficient data
# Skipping AMD-2022-03-02-13.0 due to insufficient data
# Skipping PYPL-2022-03-09-11.0 due to insufficient data
# Skipping ABNB-2022-02-17-15.0 due to insufficient data
# Skipping SPY-2022-02-18-14.0 due to insufficient data
# Skipping QQQ-2022-02-18-14.0 due to insufficient data
# Skipping DIS-2022-02-25-15.0 due to insufficient data
# Skipping XOM-2022-02-24-10.0 due to insufficient data
# Skipping ADBE-2022-03-07-10.0 due to insufficient data
# Skipping INTC-2022-02-14-13.0 due to insufficient data
# Skipping ADBE-2022-02-16-11.0 due to insufficient data
# Skipping CSCO-2022-03-10-12.0 due to insufficient data
# Skipping MSFT-2022-03-04-13.0 due to insufficient data
# Skipping BA-2022-03-03-10.0 due to insufficient data
# Skipping CSCO-2022-03-09-13.0 due to insufficient data
# Skipping AAPL-2022-02-16-13.0 due to insufficient data
# Skipping SQ-2022-02-23-11.0 due to insufficient data
# Skipping AAPL-2022-02-17-10.0 due to insufficient data
# Skipping QQQ-2022-02-24-14.0 due to insufficient data
# Skipping NVDA-2022-02-24-11.0 due to insufficient data
# Skipping DOCU-2022-03-08-13.0 due to insufficient data
# Skipping TSM-2022-03-02-12.0 due to insufficient data
# Skipping CSCO-2022-03-09-10.0 due to insufficient data
# Skipping JPM-2022-02-28-15.0 due to insufficient data
# Skipping NFLX-2022-03-01-12.0 due to insufficient data
# Skipping C-2022-02-14-15.0 due to insufficient data
# Skipping NFLX-2022-03-07-12.0 due to insufficient data
# Skipping QCOM-2022-03-02-15.0 due to insufficient data
# Skipping IWM-2022-03-10-15.0 due to insufficient data
# Skipping CVX-2022-03-01-10.0 due to insufficient data
# Skipping AVGO-2022-03-03-14.0 due to insufficient data
# Skipping JPM-2022-02-15-11.0 due to insufficient data
# Skipping NKE-2022-03-03-12.0 due to insufficient data
# Skipping DOCU-2022-02-25-14.0 due to insufficient data
# Skipping BAC-2022-03-04-12.0 due to insufficient data
# Skipping QCOM-2022-03-01-15.0 due to insufficient data
# Skipping IWM-2022-03-04-12.0 due to insufficient data
# Skipping ABNB-2022-02-23-10.0 due to insufficient data
# Skipping WMT-2022-03-03-12.0 due to insufficient data
# Skipping NFLX-2022-03-10-14.0 due to insufficient data
# Skipping QCOM-2022-02-23-10.0 due to insufficient data
# Skipping QQQ-2022-02-18-11.0 due to insufficient data
# Skipping SQ-2022-03-10-14.0 due to insufficient data
# Skipping QCOM-2022-02-25-13.0 due to insufficient data
# Skipping BA-2022-02-16-14.0 due to insufficient data
# Skipping INTC-2022-02-25-12.0 due to insufficient data
# Skipping PLTR-2022-02-15-11.0 due to insufficient data
# Skipping XOM-2022-03-02-12.0 due to insufficient data
# Skipping NVDA-2022-03-07-14.0 due to insufficient data
# Skipping QQQ-2022-03-03-10.0 due to insufficient data
# Skipping C-2022-02-28-14.0 due to insufficient data
# Skipping QQQ-2022-02-15-13.0 due to insufficient data
# Skipping C-2022-03-03-12.0 due to insufficient data
# Skipping TGT-2022-02-22-14.0 due to insufficient data
# Skipping IWM-2022-02-22-15.0 due to insufficient data
# Skipping XOM-2022-02-23-10.0 due to insufficient data
# Skipping WMT-2022-02-24-11.0 due to insufficient data
# Skipping PLTR-2022-03-04-13.0 due to insufficient data
# Skipping TSM-2022-03-08-11.0 due to insufficient data
# Skipping PYPL-2022-02-18-15.0 due to insufficient data
# Skipping NFLX-2022-02-23-11.0 due to insufficient data
# Skipping AAPL-2022-03-10-14.0 due to insufficient data
# Skipping AXP-2022-02-17-13.0 due to insufficient data
# Skipping WMT-2022-02-15-12.0 due to insufficient data
# Skipping V-2022-02-17-10.0 due to insufficient data
# Skipping AAPL-2022-02-23-10.0 due to insufficient data
# Skipping NKE-2022-03-04-15.0 due to insufficient data
# Skipping GM-2022-02-24-15.0 due to insufficient data
# Skipping SBUX-2022-02-15-14.0 due to insufficient data
# Skipping AMZN-2022-02-28-11.0 due to insufficient data
# Skipping SQ-2022-02-18-11.0 due to insufficient data
# Skipping SPY-2022-02-25-13.0 due to insufficient data
# Skipping AVGO-2022-02-14-11.0 due to insufficient data
# Skipping PLTR-2022-03-04-11.0 due to insufficient data
# Skipping INTC-2022-03-07-10.0 due to insufficient data
# Skipping AMD-2022-03-07-14.0 due to insufficient data
# Skipping NVDA-2022-02-23-11.0 due to insufficient data
# Skipping TSM-2022-02-24-15.0 due to insufficient data
# Skipping BA-2022-02-15-10.0 due to insufficient data
# Skipping DOCU-2022-02-15-13.0 due to insufficient data
# Skipping INTC-2022-02-25-13.0 due to insufficient data
# Skipping BA-2022-02-28-14.0 due to insufficient data
# Skipping ABNB-2022-02-23-13.0 due to insufficient data
# Skipping ABNB-2022-02-16-13.0 due to insufficient data
# Skipping QCOM-2022-02-24-14.0 due to insufficient data
# Skipping NVDA-2022-03-09-14.0 due to insufficient data
# Skipping ABNB-2022-02-25-10.0 due to insufficient data
# Skipping WMT-2022-03-10-11.0 due to insufficient data
# Skipping XOM-2022-03-07-14.0 due to insufficient data
# Skipping TGT-2022-03-03-11.0 due to insufficient data
# Skipping TGT-2022-02-28-13.0 due to insufficient data
# Skipping AVGO-2022-03-01-13.0 due to insufficient data
# Skipping SNOW-2022-02-18-11.0 due to insufficient data
# Skipping BAC-2022-02-18-10.0 due to insufficient data
# Skipping ADBE-2022-03-01-12.0 due to insufficient data
# Skipping CVX-2022-03-02-12.0 due to insufficient data
# Skipping AAPL-2022-02-28-10.0 due to insufficient data
# Skipping AVGO-2022-03-01-15.0 due to insufficient data
# Skipping UBER-2022-02-14-11.0 due to insufficient data
# Skipping MSFT-2022-02-17-12.0 due to insufficient data
# Skipping ABNB-2022-03-03-14.0 due to insufficient data
# Skipping NVDA-2022-02-17-15.0 due to insufficient data
# Skipping GOOG-2022-02-28-10.0 due to insufficient data
# Skipping INTC-2022-03-07-11.0 due to insufficient data
# Skipping SBUX-2022-02-23-11.0 due to insufficient data
# Skipping QCOM-2022-03-09-15.0 due to insufficient data
# Skipping NKE-2022-02-18-15.0 due to insufficient data
# Skipping UBER-2022-02-23-15.0 due to insufficient data
# Skipping NVDA-2022-03-03-14.0 due to insufficient data
# Skipping TGT-2022-03-08-14.0 due to insufficient data
# Skipping CSCO-2022-02-15-13.0 due to insufficient data
# Skipping NVDA-2022-03-10-12.0 due to insufficient data
# Skipping C-2022-02-22-10.0 due to insufficient data
# Skipping ADBE-2022-02-11-10.0 due to insufficient data
# Skipping GM-2022-02-11-10.0 due to insufficient data
# Skipping QCOM-2022-02-11-11.0 due to insufficient data
# Skipping UBER-2022-02-11-11.0 due to insufficient data
# Skipping AAPL-2022-02-11-12.0 due to insufficient data
# Skipping SNOW-2022-02-11-12.0 due to insufficient data
# Skipping GM-2022-02-11-12.0 due to insufficient data
# Skipping AXP-2022-02-11-12.0 due to insufficient data
# Skipping SNOW-2022-02-11-13.0 due to insufficient data
# Skipping AAPL-2022-02-11-14.0 due to insufficient data
# Skipping NVDA-2022-02-11-14.0 due to insufficient data
# Skipping V-2022-02-11-15.0 due to insufficient data
# Skipping CVX-2022-02-11-15.0 due to insufficient data

# %%
model = model_pipeline(
    config,features_cont,features_cat,X_train, y_train, X_test, y_test)
# Out:
# TCNClassifier(
#   (tcn): TemporalConvolutionNetwork(
#     (network): Sequential(
#       (0): TemporalCasualLayer(
#         (net): Sequential(
#           (conv1): Conv1d(21, 128, kernel_size=(7,), stride=(1,), padding=(6,))
#           (crop1): Crop()
#           (act1): ReLU()
#           (dropout1): Dropout(p=0.3, inplace=False)
#         )
#         (bias): Conv1d(21, 128, kernel_size=(1,), stride=(1,))
#         (relu): ReLU()
#       )
#       (1): TemporalCasualLayer(
#         (net): Sequential(
#           (conv1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(12,), dilation=(2,))
#           (crop1): Crop()
#           (act1): ReLU()
#           (dropout1): Dropout(p=0.3, inplace=False)
#         )
#         (relu): ReLU()
#       )
#     )
#   )
#   (linear): Linear(in_features=128, out_features=2, bias=True)
# )
# Epoch 0: Train loss: 0.665570080280304, Validation loss: 0.6084348559379578
# Epoch 10: Train loss: 0.6817315816879272, Validation loss: 0.5785516500473022
# Epoch 20: Train loss: 0.6805120706558228, Validation loss: 0.5887516140937805
# Epoch 30: Train loss: 0.6985875964164734, Validation loss: 0.5895144939422607
# Epoch 40: Train loss: 0.6712058186531067, Validation loss: 0.5865277051925659
# Epoch 50: Train loss: 0.6756516098976135, Validation loss: 0.5938736796379089
# Epoch 60: Train loss: 0.6919856667518616, Validation loss: 0.5981943607330322
# Epoch 70: Train loss: 0.6492748260498047, Validation loss: 0.5924737453460693
# Epoch 80: Train loss: 0.6325525045394897, Validation loss: 0.5926540493965149
# Epoch 90: Train loss: 0.6564363837242126, Validation loss: 0.5819628238677979
# Epoch 100: Train loss: 0.706701397895813, Validation loss: 0.5923799276351929
# Epoch 110: Train loss: 0.6856880187988281, Validation loss: 0.5854396224021912
# Epoch 120: Train loss: 0.6490973234176636, Validation loss: 0.5923965573310852
# Epoch 130: Train loss: 0.6764988303184509, Validation loss: 0.5805593729019165
# Epoch 140: Train loss: 0.6617258787155151, Validation loss: 0.5861097574234009
# Epoch 150: Train loss: 0.6666011810302734, Validation loss: 0.5876947641372681
# Epoch 160: Train loss: 0.6523678302764893, Validation loss: 0.6023332476615906
# Epoch 170: Train loss: 0.6937724947929382, Validation loss: 0.5738821625709534
# Epoch 180: Train loss: 0.6938498616218567, Validation loss: 0.5907941460609436
# Epoch 190: Train loss: 0.6943424940109253, Validation loss: 0.5882003307342529
# Epoch 200: Train loss: 0.6395304203033447, Validation loss: 0.5902246236801147
# Epoch 210: Train loss: 0.6712013483047485, Validation loss: 0.5889169573783875
# Epoch 220: Train loss: 0.6671690940856934, Validation loss: 0.5943145155906677
# Epoch 230: Train loss: 0.6525039076805115, Validation loss: 0.5880123972892761
# Epoch 240: Train loss: 0.6712513566017151, Validation loss: 0.583052396774292
# Epoch 250: Train loss: 0.6986182332038879, Validation loss: 0.5760955214500427
# Epoch 260: Train loss: 0.6714451313018799, Validation loss: 0.5783063769340515
# Epoch 270: Train loss: 0.6757887005805969, Validation loss: 0.5895013809204102
# Epoch 280: Train loss: 0.6332588791847229, Validation loss: 0.5845603346824646
# Epoch 290: Train loss: 0.720481276512146, Validation loss: 0.5832562446594238
# Epoch 300: Train loss: 0.6608574986457825, Validation loss: 0.5696351528167725
# Epoch 310: Train loss: 0.7075363993644714, Validation loss: 0.5680356621742249
# Epoch 320: Train loss: 0.675669252872467, Validation loss: 0.5995149612426758
# Epoch 330: Train loss: 0.6806764006614685, Validation loss: 0.5836718678474426
# Epoch 340: Train loss: 0.653236985206604, Validation loss: 0.5908796191215515
# Epoch 350: Train loss: 0.6839197278022766, Validation loss: 0.5974260568618774
# Epoch 360: Train loss: 0.6843997240066528, Validation loss: 0.5934402346611023
# Epoch 370: Train loss: 0.6455872058868408, Validation loss: 0.5783126354217529
# Epoch 380: Train loss: 0.6390792727470398, Validation loss: 0.5876851677894592
# Epoch 390: Train loss: 0.6806203722953796, Validation loss: 0.587044358253479
# Epoch 400: Train loss: 0.6476510763168335, Validation loss: 0.5845238566398621
# Epoch 410: Train loss: 0.6871433258056641, Validation loss: 0.5787698030471802
# Epoch 420: Train loss: 0.6178203225135803, Validation loss: 0.5834051370620728
# Epoch 430: Train loss: 0.6838279366493225, Validation loss: 0.5971349477767944
# Epoch 440: Train loss: 0.6758793592453003, Validation loss: 0.5877611637115479
# Epoch 450: Train loss: 0.64536052942276, Validation loss: 0.577602744102478
# Epoch 460: Train loss: 0.6804087162017822, Validation loss: 0.5877988338470459
# Epoch 470: Train loss: 0.7320224046707153, Validation loss: 0.5948761105537415
# Epoch 480: Train loss: 0.6495320796966553, Validation loss: 0.5694120526313782
# Epoch 490: Train loss: 0.6878837943077087, Validation loss: 0.5979306101799011
# Epoch 500: Train loss: 0.6987264156341553, Validation loss: 0.5885307788848877
# Epoch 510: Train loss: 0.6526041030883789, Validation loss: 0.5861366391181946
# Epoch 520: Train loss: 0.6952258944511414, Validation loss: 0.5869265198707581
# Epoch 530: Train loss: 0.6989472508430481, Validation loss: 0.5740116238594055
# Epoch 540: Train loss: 0.6665022969245911, Validation loss: 0.5868255496025085
# Epoch 550: Train loss: 0.6153129935264587, Validation loss: 0.5776839256286621
# Epoch 560: Train loss: 0.7082117199897766, Validation loss: 0.5663960576057434
# Epoch 570: Train loss: 0.6569147706031799, Validation loss: 0.5846304297447205
# Epoch 580: Train loss: 0.6756418347358704, Validation loss: 0.5938725471496582
# Epoch 590: Train loss: 0.6443144679069519, Validation loss: 0.5900669693946838
# Epoch 600: Train loss: 0.6930680274963379, Validation loss: 0.5947273373603821
# Epoch 610: Train loss: 0.6932392120361328, Validation loss: 0.593955397605896
# Epoch 620: Train loss: 0.7099949717521667, Validation loss: 0.5846834182739258
# Epoch 630: Train loss: 0.671320378780365, Validation loss: 0.5947484374046326
# Epoch 640: Train loss: 0.6986657381057739, Validation loss: 0.5890772342681885
# Epoch 650: Train loss: 0.6662848591804504, Validation loss: 0.5805935263633728
# Epoch 660: Train loss: 0.6663005948066711, Validation loss: 0.5819350481033325
# Epoch 670: Train loss: 0.6712121367454529, Validation loss: 0.5920336842536926
# Epoch 680: Train loss: 0.6720481514930725, Validation loss: 0.5704670548439026
# Epoch 690: Train loss: 0.6802465319633484, Validation loss: 0.590337872505188
# Epoch 700: Train loss: 0.6946479678153992, Validation loss: 0.5873904228210449
# Epoch 710: Train loss: 0.6663289666175842, Validation loss: 0.5752257704734802
# Epoch 720: Train loss: 0.6434826850891113, Validation loss: 0.5874412059783936
# Epoch 730: Train loss: 0.6957314610481262, Validation loss: 0.582221508026123
# Epoch 740: Train loss: 0.6809805035591125, Validation loss: 0.5842584371566772
# Epoch 750: Train loss: 0.6505707502365112, Validation loss: 0.5750349164009094
# Epoch 760: Train loss: 0.6895037889480591, Validation loss: 0.5891017913818359
# Epoch 770: Train loss: 0.7148231267929077, Validation loss: 0.592473566532135
# Epoch 780: Train loss: 0.6669663190841675, Validation loss: 0.5932380557060242
# Epoch 790: Train loss: 0.6800304651260376, Validation loss: 0.593927264213562
